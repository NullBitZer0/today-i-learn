# %%
import dagshub
import mlflow

dagshub.init(
    repo_owner="NullBitZer0",
    repo_name="today-i-learn",
    mlflow=True
)

with mlflow.start_run():

    mlflow.log_param("model", "test")

    mlflow.log_metric("accuracy", 0.95)

    print("Experiment logged successfully")
# Out:
# Initialized MLflow to track repo "NullBitZer0/today-i-learn"
# Repository NullBitZer0/today-i-learn initialized!
# Experiment logged successfully
# 🏃 View run chill-hawk-806 at: https://dagshub.com/NullBitZer0/today-i-learn.mlflow/#/experiments/0/runs/19ecda977e564300a419c766c1deabd3
# 🧪 View experiment at: https://dagshub.com/NullBitZer0/today-i-learn.mlflow/#/experiments/0

# %%
import pandas as pd

df = pd.DataFrame({
    "age": [20, 25, 30],
    "salary": [1000, 2000, 3000]
})

df.to_csv("../dvc and mlflow/data/sample.csv", index=False)
